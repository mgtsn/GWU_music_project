# %%
# Dependencies
import json
import requests
import time
import pandas as pd
from config import pword

# %%
# Request credentials using username and password
url = "https://api.hooktheory.com/v1/users/auth"
header = {"accept": "application/json", 
          "Content-Type": "application/json",
          "username": 'mgtsn',
          "password": pword}

response = requests.post(url, data=header).json()

#save the key and id from response
key = response['activkey']
user_id = response['id']

#create header used for queries
bearer = f'Bearer {key}'
a_header = {'Authorization':bearer}

# %%
c = requests.session()
c.headers = a_header

# %%
#set query url and parameters
url = "https://api.hooktheory.com/v1/trends/songs"
params = {'cp':'', 'page':1}

#list progressions we want to check
progressions = ['1,5,4,6', '1,4,5', '1,4,6,5', '6,4,1,5', '1,6,4,5']

#initialize a list to store data
songs = []

# %%
comm = '''params['cp'] = progressions[0]
r = c.get(url, params = params)
response = r.json()
r.headers['X-Rate-Limit-Reset']'''

# %%
for cp in progressions:
    params['cp'] = cp
    page = 1
    while page > 0:
        params['page'] = page
        r = c.get(url, params = params)
        count = int(r.headers['X-Rate-Limit-Remaining'])
        if len(songs) > 1000:
            break
        if count == 0:
            wait = int(r.headers['X-Rate-Limit-Reset'])
            print(len(songs))
            print(f'waiting {wait} seconds')
            time.sleep(wait)
        response = r.json()
        if len(response) == 0:
            page = 0
        else:
            for song in response:
                try:
                    song['cp'] = cp
                    songs.append(song)
                except:
                    print('error')
                    print(response)
# Out:
# 100
# waiting 10 seconds
# 240
# waiting 10 seconds
# error
# {'name': 'Too Many Requests', 'message': 'Rate limit exceeded.', 'code': 0, 'status': 429}
# error
# {'name': 'Too Many Requests', 'message': 'Rate limit exceeded.', 'code': 0, 'status': 429}
# error
# {'name': 'Too Many Requests', 'message': 'Rate limit exceeded.', 'code': 0, 'status': 429}
# error
# {'name': 'Too Many Requests', 'message': 'Rate limit exceeded.', 'code': 0, 'status': 429}
# 360
# waiting 10 seconds
# error
# {'name': 'Too Many Requests', 'message': 'Rate limit exceeded.', 'code': 0, 'status': 429}
# error
# {'name': 'Too Many Requests', 'message': 'Rate limit exceeded.', 'code': 0, 'status': 429}
# error
# {'name': 'Too Many Requests', 'message': 'Rate limit exceeded.', 'code': 0, 'status': 429}
# error
# {'name': 'Too Many Requests', 'message': 'Rate limit exceeded.', 'code': 0, 'status': 429}
# 460
# waiting 10 seconds
# 580
# waiting 10 seconds
# 700
# waiting 10 seconds
# 820
# waiting 10 seconds
# 960
# waiting 10 seconds
# error
# {'name': 'Too Many Requests', 'message': 'Rate limit exceeded.', 'code': 0, 'status': 429}
# error
# {'name': 'Too Many Requests', 'message': 'Rate limit exceeded.', 'code': 0, 'status': 429}
# error
# {'name': 'Too Many Requests', 'message': 'Rate limit exceeded.', 'code': 0, 'status': 429}
# error
# {'name': 'Too Many Requests', 'message': 'Rate limit exceeded.', 'code': 0, 'status': 429}

# %%
songs_df = pd.DataFrame(songs)
songs_df = songs_df.drop(columns='url')
songs_df.head(30)
# Out:
#                              artist       cp               section  \
# 0                   Bloodhound Gang  1,5,4,6       Intro and Verse
# 1                    Britney Spears  1,5,4,6                 Verse
# 2                           Cascada  1,5,4,6                 Verse
# 3                      Dire Straits  1,5,4,6                Chorus
# 4                              Pink  1,5,4,6                Chorus
# 5                           Rihanna  1,5,4,6                Chorus
# 6                           Rihanna  1,5,4,6            Pre-Chorus
# 7                            Avicii  1,5,4,6                 Intro
# 8                       Nicki Minaj  1,5,4,6                Chorus
# 9                       Nicki Minaj  1,5,4,6            Pre-Chorus
# 10                     Taylor Swift  1,5,4,6                Chorus
# 11                     Taylor Swift  1,5,4,6                Chorus
# 12                   Jonas Brothers  1,5,4,6                 Verse
# 13                   Jonas Brothers  1,5,4,6                Chorus
# 14                             Pink  1,5,4,6                 Verse
# 15                             Pink  1,5,4,6            Pre-Chorus
# 16  James Morrison ft Nelly Furtado  1,5,4,6                Chorus
# 17                         The Cars  1,5,4,6                Chorus
# 18                         Skrillex  1,5,4,6  Verse and Pre-Chorus
# 19                   Kelly Clarkson  1,5,4,6  Verse and Pre-Chorus
# 20                  Bloodhound Gang  1,5,4,6       Intro and Verse
# 21                   Britney Spears  1,5,4,6                 Verse
# 22                          Cascada  1,5,4,6                 Verse
# 23                     Dire Straits  1,5,4,6                Chorus
# 24                             Pink  1,5,4,6                Chorus
# 25                          Rihanna  1,5,4,6                Chorus
# 26                          Rihanna  1,5,4,6            Pre-Chorus
# 27                           Avicii  1,5,4,6                 Intro
# 28                      Nicki Minaj  1,5,4,6                Chorus
# 29                      Nicki Minaj  1,5,4,6            Pre-Chorus
#
#                        song
# 0             The Bad Touch
# 1            Out From Under
# 2       Every Time We Touch
# 3          Sultans of Swing
# 4          Raise Your Glass
# 5                 Disturbia
# 6                 Disturbia
# 7                    Levels
# 8                 Starships
# 9                 Starships
# 10                      Red
# 11                       22
# 12                Burnin up
# 13                Burnin up
# 14         Raise Your Glass
# 15         Raise Your Glass
# 16           Broken Strings
# 17       Just What I Needed
# 18             Cinema Remix
# 19  Behind These Hazel Eyes
# 20            The Bad Touch
# 21           Out From Under
# 22      Every Time We Touch
# 23         Sultans of Swing
# 24         Raise Your Glass
# 25                Disturbia
# 26                Disturbia
# 27                   Levels
# 28                Starships
# 29                Starships
